# %% [markdown]
# # NFL Player Analysis
#
# This notebook explores the dataset given in the [NFL Big Data Bowl 2021 Kaggle competition](https://www.kaggle.com/c/nfl-big-data-bowl-2021/overview). The dataset used is NFL’s Next Gen Stats 2018 data, which includes comprehensive information on all plays and players for the entire 2018 season.

# %% [markdown]
# ## Import the libraries

# %%
import sys
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import IPython
from IPython.display import display
import sklearn
import seaborn as sns

# Pandas options
pd.set_option("display.precision", 2)
pd.set_option('display.max_columns', None)

# Seaborn options
sns.set_theme()

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## NFL Player Analysis
#
# This is a second and distinct insight that we tried to do some data analysis on. We tried to cluster and classify players by their physical attributes.

# %%
from sklearn import cluster

nfl_data = pd.read_csv('data/players.csv')
nfl_data.describe(include='all')
# Out:
#            nflId height   weight   birthDate collegeName position  \
# count   1.30e+03   1303  1303.00        1303        1303     1303
# unique       NaN     29      NaN        1150         251       21
# top          NaN     73      NaN  1989-04-26     Alabama       WR
# freq         NaN    159      NaN           4          33      228
# mean    2.42e+06    NaN   222.54         NaN         NaN      NaN
# std     5.33e+05    NaN    29.48         NaN         NaN      NaN
# min     2.52e+02    NaN   159.00         NaN         NaN      NaN
# 25%     2.54e+06    NaN   200.00         NaN         NaN      NaN
# 50%     2.55e+06    NaN   216.00         NaN         NaN      NaN
# 75%     2.56e+06    NaN   242.00         NaN         NaN      NaN
# max     2.56e+06    NaN   352.00         NaN         NaN      NaN
#
#              displayName
# count               1303
# unique              1298
# top     Brandon Marshall
# freq                   2
# mean                 NaN
# std                  NaN
# min                  NaN
# 25%                  NaN
# 50%                  NaN
# 75%                  NaN
# max                  NaN

# %%
h_w = nfl_data[['height','weight','position']]
h_w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   height    1303 non-null   object
#  1   weight    1303 non-null   int64
#  2   position  1303 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 30.7+ KB

# %%
hw_filtered = h_w[(h_w['height']).map(len) <= 2]
hw_filtered
# Out:
#      height  weight position
# 0        72     190       CB
# 1        70     186       CB
# 2        69     186       SS
# 3        73     227      MLB
# 4        75     232      OLB
# ...     ...     ...      ...
# 1294     72     180       WR
# 1295     71     205       DB
# 1296     73     220        P
# 1300     78     231       QB
# 1301     69     187       CB
#
# [1063 rows x 3 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

data = hw_filtered[['height','weight']]
scaler.fit(data)

hw_filtered[['height','weight']] = scaler.transform(data[['height','weight']])

# %%
from sklearn.model_selection import train_test_split

X = hw_filtered.drop(columns=['position'])
y = hw_filtered['position'].to_numpy()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
from sklearn.cluster import KMeans

k=10
kmeans = KMeans(n_clusters=k, n_jobs=-1, verbose=0)
y_pred = kmeans.fit_predict(X_train)

# %%
y_train = y_pred
labels1 = pd.DataFrame(kmeans.labels_,columns=['Cluster ID'])
result1 = pd.concat((X,labels1), axis=1)
result1.plot.scatter(x='height',y='weight',c='Cluster ID',colormap='jet')
# Out:
# <AxesSubplot:xlabel='height', ylabel='weight'>

# %%
result1.plot.scatter(x='height',y='weight',c='Cluster ID',colormap='jet')
# Out:
# <AxesSubplot:xlabel='height', ylabel='weight'>

# %%
import matplotlib.pyplot as plt

plt.scatter(X['height'], X['weight'])

# %% [markdown]
# ## DBSCAN

# %%
from sklearn.cluster import DBSCAN

db = DBSCAN(eps=.4).fit(X)
labels1 = pd.DataFrame(db.labels_,columns=['Cluster ID'])
result1 = pd.concat((X,labels1), axis=1)
result1.plot.scatter(x='height',y='weight',c='Cluster ID',colormap='jet')
# Out:
# <AxesSubplot:xlabel='height', ylabel='weight'>

# %% [markdown]
# ## Classifying Players
#
# Seeing as clustering players clearly didn't work, we tried to classify the players into their positions instead. First we did so with only weight and height, but then we also appended NFL combine information.

# %%
from sklearn.metrics import accuracy_score, precision_score, f1_score, recall_score

def print_scores(y_pred, y_test):
    print('Summary')
    print('-'*60)
    print(f'Accuracy: {accuracy_score(y_pred, y_test)}')
    print(f'Precision: {precision_score(y_pred, y_test, average="weighted")}')
    print(f'Recall: {recall_score(y_pred, y_test, average="weighted")}')
    print(f'F1 Score: {f1_score(y_pred, y_test, average="weighted")}')

# %%
pd.unique(hw_filtered['position'])
# Out:
# array(['CB', 'SS', 'MLB', 'OLB', 'FS', 'QB', 'TE', 'WR', 'DE', 'RB', 'LB',
#        'FB', 'ILB', 'DB', 'S', 'HB', 'NT', 'P', 'LS', 'K', 'DT'],
#       dtype=object)

# %%
df = hw_filtered
df = df[df['position'].isin(['RB','TE','WR','QB'])]

# %%
X = df.drop(columns=['position'])
y = df['position'].to_numpy()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

dt = DecisionTreeClassifier(max_depth = 1, max_features=None)
dt.fit(X_train, y_train)

dt = DecisionTreeClassifier()
params = {
    'max_depth': list(range(1, 50)),
    'max_features': [10, 20, 30, 40, 60, 100, 120, 'log2', None]
}
clf = GridSearchCV(dt, params, n_jobs=-1)
clf.fit(X_train, y_train)
clf.best_params_
# Out:
# {'max_depth': 5, 'max_features': None}

# %%
y_pred = clf.predict(X_test)
print_scores(y_pred, y_test)
# Out:
# Summary
# ------------------------------------------------------------
# Accuracy: 0.7777777777777778
# Precision: 0.8638888888888889
# Recall: 0.7777777777777778
# F1 Score: 0.8049732173571184

# %% [markdown]
# ## With Combine Stats
#
# Since the player data didn't work too well, we will use the NFL Combine dataset for classification.

# %%
nfl_data = pd.read_csv('data/combine.csv')
nfl_data.describe(include='all')
# Out:
#                                                       url     pick  team  \
# count                                                4419  4162.00  2832
# unique                                               4404      NaN    34
# top     https://www.sports-reference.com/cfb/players/c...      NaN   SFO
# freq                                                    2      NaN   109
# mean                                                  NaN   171.04   NaN
# std                                                   NaN   105.85   NaN
# min                                                   NaN     1.00   NaN
# 25%                                                   NaN    75.00   NaN
# 50%                                                   NaN   161.00   NaN
# 75%                                                   NaN   300.00   NaN
# max                                                   NaN   300.00   NaN
#
#            year   pos       player              college  missing_combine_vals  \
# count   4419.00  4419         4419                 4419               4419.00
# unique      NaN    23         4347                  179                   NaN
# top         NaN    WR  Chris Brown  Southern California                   NaN
# freq        NaN   741            4                  112                   NaN
# mean    2009.93   NaN          NaN                  NaN                  1.45
# std        5.15   NaN          NaN                  NaN                  1.77
# min     2000.00   NaN          NaN                  NaN                  0.00
# 25%     2006.00   NaN          NaN                  NaN                  0.00
# 50%     2010.00   NaN          NaN                  NaN                  1.00
# 75%     2014.00   NaN          NaN                  NaN                  2.50
# max     2018.00   NaN          NaN                  NaN                  6.00
#
#         height_inches   weight    forty  vertical    bench    broad  \
# count         4419.00  4419.00  4318.00   3506.00  3023.00  3482.00
# unique            NaN      NaN      NaN       NaN      NaN      NaN
# top               NaN      NaN      NaN       NaN      NaN      NaN
# freq              NaN      NaN      NaN       NaN      NaN      NaN
# mean            73.46   235.52     4.71     33.35    20.34   115.55
# std              2.55    39.79     0.26      3.99     6.30     8.37
# min             65.00   149.00     4.22     19.00     2.00    74.00
# 25%             72.00   204.00     4.52     31.00    16.00   111.00
# 50%             73.00   227.00     4.65     33.50    20.00   116.00
# 75%             75.00   257.00     4.85     36.00    24.00   121.00
# max             82.00   369.00     6.00     46.00    49.00   147.00
#
#         threecone  shuttle  defense.ast.tackles  defense.fum.forced  \
# count     2866.00  2914.00              4419.00             4419.00
# unique        NaN      NaN                  NaN                 NaN
# top           NaN      NaN                  NaN                 NaN
# freq          NaN      NaN                  NaN                 NaN
# mean         7.18     4.34                24.09                0.65
# std          0.35     0.23                37.96                1.52
# min          6.28     3.73                 0.00                0.00
# 25%          6.94     4.18                 0.00                0.00
# 50%          7.12     4.31                 0.00                0.00
# 75%          7.37     4.47                43.00                0.00
# max          9.04     5.56               242.00               16.00
#
#         defense.fum.rec  defense.fum.tds  defense.fum.yds  defense.games  \
# count           4419.00          4419.00          4419.00        4419.00
# unique              NaN              NaN              NaN            NaN
# top                 NaN              NaN              NaN            NaN
# freq                NaN              NaN              NaN            NaN
# mean               0.30             0.08             2.70          17.17
# std                0.95             0.31            11.91          19.54
# min                0.00             0.00            -1.00           0.00
# 25%                0.00             0.00             0.00           0.00
# 50%                0.00             0.00             0.00           0.00
# 75%                0.00             0.00             0.00          36.00
# max               33.00             3.00           184.00          56.00
#
#         defense.int  defense.int.td  defense.int.yards  defense.loss.tackles  \
# count       4419.00         4419.00            4419.00               4419.00
# unique          NaN             NaN                NaN                   NaN
# top             NaN             NaN                NaN                   NaN
# freq            NaN             NaN                NaN                   NaN
# mean           1.66            0.19              23.48                  6.90
# std            3.15            0.57              53.09                 11.57
# min            0.00            0.00             -25.00                  0.00
# 25%            0.00            0.00               0.00                  0.00
# 50%            0.00            0.00               0.00                  0.00
# 75%            2.00            0.00              18.00                 10.50
# max           24.00            5.00             494.00                 75.00
#
#         defense.pd  defense.sacks  defense.seasons  defense.solo.tackes  \
# count      4419.00        4419.00          4419.00              4419.00
# unique         NaN            NaN              NaN                  NaN
# top            NaN            NaN              NaN                  NaN
# freq           NaN            NaN              NaN                  NaN
# mean          2.17           2.75             1.55                35.93
# std           5.03           5.69             1.74                53.82
# min           0.00           0.00             0.00                 0.00
# 25%           0.00           0.00             0.00                 0.00
# 50%           0.00           0.00             0.00                 0.00
# 75%           2.00           2.00             3.00                68.00
# max          53.00          36.00             6.00               338.00
#
#         defense.tackles passing.attempts  passing.comp.pct  \
# count           4419.00             4419           4419.00
# unique              NaN              285               NaN
# top                 NaN                0               NaN
# freq                NaN             4103               NaN
# mean              60.02              NaN             15.43
# std               89.41              NaN             57.02
# min                0.00              NaN              0.00
# 25%                0.00              NaN              0.00
# 50%                0.00              NaN              0.00
# 75%              114.00              NaN              0.00
# max              532.00              NaN            343.00
#
#        passing.completions  passing.games  passing.pass.ints  \
# count                 4419        4419.00            4419.00
# unique                 266            NaN                NaN
# top                      0            NaN                NaN
# freq                  4103            NaN                NaN
# mean                   NaN           2.77               1.96
# std                    NaN          10.27               7.75
# min                    NaN           0.00               0.00
# 25%                    NaN           0.00               0.00
# 50%                    NaN           0.00               0.00
# 75%                    NaN           0.00               0.00
# max                    NaN          61.00              80.00
#
#         passing.pass.tds passing.pass.yards  passing.seasons  receiving.games  \
# count            4419.00               4419          4419.00          4419.00
# unique               NaN                314              NaN              NaN
# top                  NaN                  0              NaN              NaN
# freq                 NaN               4103              NaN              NaN
# mean                4.19                NaN             0.26             9.32
# std                16.70                NaN             0.97            17.30
# min                 0.00                NaN             0.00             0.00
# 25%                 0.00                NaN             0.00             0.00
# 50%                 0.00                NaN             0.00             0.00
# 75%                 0.00                NaN             0.00             0.00
# max               155.00                NaN             5.00            56.00
#
#         receiving.rec.td receiving.rec.yards  receiving.receptions  \
# count            4419.00                4419               4419.00
# unique               NaN                 903                   NaN
# top                  NaN                   0                   NaN
# freq                 NaN                3366                   NaN
# mean                3.36                 NaN                 29.65
# std                 7.35                 NaN                 61.87
# min                 0.00                 NaN                  0.00
# 25%                 0.00                 NaN                  0.00
# 50%                 0.00                 NaN                  0.00
# 75%                 0.00                 NaN                  0.00
# max                60.00                 NaN                387.00
#
#         receiving.rush.att  receiving.rush.td receiving.rush.yds  \
# count              4419.00            4419.00               4419
# unique                 NaN                NaN                253
# top                    NaN                NaN                  0
# freq                   NaN                NaN               3733
# mean                  2.24               0.12                NaN
# std                  10.06               0.78                NaN
# min                   0.00               0.00                NaN
# 25%                   0.00               0.00                NaN
# 50%                   0.00               0.00                NaN
# 75%                   0.00               0.00                NaN
# max                 182.00              28.00                NaN
#
#         receiving.scrim.plays  receiving.scrim.tds receiving.scrim.yds  \
# count                 4419.00              4419.00                4419
# unique                    NaN                  NaN                 914
# top                       NaN                  NaN                   0
# freq                      NaN                  NaN                3366
# mean                    31.89                 3.48                 NaN
# std                     67.32                 7.61                 NaN
# min                      0.00                 0.00                 NaN
# 25%                      0.00                 0.00                 NaN
# 50%                      0.00                 0.00                 NaN
# 75%                      0.00                 0.00                 NaN
# max                    398.00                60.00                 NaN
#
#         receiving.seasons  rushing.games  rushing.rec.td rushing.rec.yards  \
# count             4419.00        4419.00         4419.00              4419
# unique                NaN            NaN             NaN               446
# top                   NaN            NaN             NaN                 0
# freq                  NaN            NaN             NaN              3843
# mean                 0.83           5.12            0.37               NaN
# std                  1.53          13.52            1.44               NaN
# min                  0.00           0.00            0.00               NaN
# 25%                  0.00           0.00            0.00               NaN
# 50%                  0.00           0.00            0.00               NaN
# 75%                  0.00           0.00            0.00               NaN
# max                  6.00          54.00           19.00               NaN
#
#         rushing.receptions rushing.rush.att  rushing.rush.td rushing.rush.yds  \
# count              4419.00             4419          4419.00             4419
# unique                 NaN              432              NaN              541
# top                    NaN                0              NaN                0
# freq                   NaN             3834              NaN             3835
# mean                  6.58              NaN             3.04              NaN
# std                  21.24              NaN             9.28              NaN
# min                   0.00              NaN             0.00              NaN
# 25%                   0.00              NaN             0.00              NaN
# 50%                   0.00              NaN             0.00              NaN
# 75%                   0.00              NaN             0.00              NaN
# max                 303.00              NaN            77.00              NaN
#
#        rushing.scrim.plays  rushing.scrim.tds rushing.scrim.yds  \
# count                 4419            4419.00              4419
# unique                 435                NaN               547
# top                      0                NaN                 0
# freq                  3834                NaN              3835
# mean                   NaN               3.41               NaN
# std                    NaN              10.24               NaN
# min                    NaN               0.00               NaN
# 25%                    NaN               0.00               NaN
# 50%                    NaN               0.00               NaN
# 75%                    NaN               0.00               NaN
# max                    NaN              87.00               NaN
#
#         rushing.seasons  num_murders  purple.drank.incidents
# count           4419.00     4.42e+03                4.42e+03
# unique              NaN          NaN                     NaN
# top                 NaN          NaN                     NaN
# freq                NaN          NaN                     NaN
# mean               0.47     3.39e-03                3.39e-03
# std                1.23     1.98e-01                1.68e-01
# min                0.00     0.00e+00                0.00e+00
# 25%                0.00     0.00e+00                0.00e+00
# 50%                0.00     0.00e+00                0.00e+00
# 75%                0.00     0.00e+00                0.00e+00
# max                6.00     1.30e+01                1.00e+01

# %%
df = nfl_data
df.isnull().sum()
# Out:
# url                          0
# pick                       257
# team                      1587
# year                         0
# pos                          0
#                           ...
# rushing.scrim.tds            0
# rushing.scrim.yds            0
# rushing.seasons              0
# num_murders                  0
# purple.drank.incidents       0
# Length: 63, dtype: int64

# %%
relevant_attrs = ['pos','height_inches','weight','forty','vertical','bench','broad', 'threecone','shuttle']
df = nfl_data[relevant_attrs]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4419 entries, 0 to 4418
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pos            4419 non-null   object
#  1   height_inches  4419 non-null   int64
#  2   weight         4419 non-null   int64
#  3   forty          4318 non-null   float64
#  4   vertical       3506 non-null   float64
#  5   bench          3023 non-null   float64
#  6   broad          3482 non-null   float64
#  7   threecone      2866 non-null   float64
#  8   shuttle        2914 non-null   float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 310.8+ KB

# %%
df = df.dropna()
df = df[df['pos'].isin(['RB','TE','WR','QB'])]
df.isnull().sum()
# Out:
# pos              0
# height_inches    0
# weight           0
# forty            0
# vertical         0
# bench            0
# broad            0
# threecone        0
# shuttle          0
# dtype: int64

# %%
df['pos'].value_counts()
# Out:
# WR    237
# RB    214
# TE    170
# QB     10
# Name: pos, dtype: int64

# %% [markdown]
# ## NFL Combine Data Exploration

# %%
splot = sns.catplot(data=df, x='pos', kind='count').set(xlabel='Position', ylabel='Count')
for ax in splot.axes.ravel():
    for p in ax.patches:
        ax.annotate(format(p.get_height(), '2d'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
# Convert pos to encoded integer
df['pos_encoded'], uniques = pd.factorize(df['pos'])

# Plot heatmap which shows correlations
plt.figure(figsize=(18, 10)) 
colormap = sns.diverging_palette(220, 10, as_cmap = True)
sns.heatmap(df.corr(), annot=True, cmap=colormap)
plt.show()

# %%
df.corr()['pos_encoded']
# Out:
# height_inches    0.44
# weight           0.78
# forty            0.64
# vertical        -0.27
# bench            0.46
# broad           -0.41
# threecone        0.44
# shuttle          0.27
# pos_encoded      1.00
# Name: pos_encoded, dtype: float64

# %%
from scipy.stats import f_oneway

print('One-way Anova             p-values                       p > 0.05')
print('-'*70)
test_df = df.drop(columns=['pos'])
F, p = f_oneway(
    test_df[test_df['pos_encoded'] == 0], 
    test_df[test_df['pos_encoded'] == 1],
    test_df[test_df['pos_encoded'] == 2],
    test_df[test_df['pos_encoded'] == 3]
)
for i in range(len(test_df.columns)):
    print(f'{test_df.columns[i].ljust(25)}: {str(p[i]).ljust(30)} {p[i] > 0.05}')
# Out:
# One-way Anova             p-values                       p > 0.05
# ----------------------------------------------------------------------
# height_inches            : 1.8328683934363592e-115        False
# weight                   : 4.175828907301369e-177         False
# forty                    : 4.545036721171615e-87          False
# vertical                 : 2.1635542580338273e-12         False
# bench                    : 8.248176720376504e-47          False
# broad                    : 3.7816387832883488e-25         False
# threecone                : 5.5292040325509644e-30         False
# shuttle                  : 8.112487960549676e-14          False
# pos_encoded              : 0.0                            False

# %%
X = df.drop(columns=['pos'])
y = df['pos'].to_numpy()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
dt = DecisionTreeClassifier()
params = {
    'max_depth': list(range(1, 10)),
    'max_features': [60, 100, 120, 'log2', None]
}
clf = GridSearchCV(dt, params)
clf.fit(X_train, y_train)
clf.best_params_
# Out:
# {'max_depth': 6, 'max_features': None}

# %%
y_pred = clf.predict(X_test)
print_scores(y_pred, y_test)
# Out:
# Summary
# ------------------------------------------------------------
# Accuracy: 0.90625
# Precision: 0.9089583333333334
# Recall: 0.90625
# F1 Score: 0.9064851588628763
